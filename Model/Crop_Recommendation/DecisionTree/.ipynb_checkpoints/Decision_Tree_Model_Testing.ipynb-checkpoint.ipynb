# %%
import joblib
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
decisionTree=joblib.load('crop_recommendation_model_dt.pkl')
best_params = joblib.load('best_params_dt.pkl')
feature_names = joblib.load('feature_names.pkl')

# %%
test_samples = [
    [90, 42, 43, 20.88, 82.0, 6.5, 202.94],
    [40, 40, 40, 25.0, 80.0, 7.0, 150.0],    
    [80, 50, 50, 30.0, 60.0, 6.8, 100.0]     
]

# %%
# Example: mapping numeric classes to crop names
crop_labels = {
    0:"apple",
    1:"banana",
    2:"blackgram",
    3:"chickpea",
    4:"coconut",
    5:"coffee",
    6:"cotton",
    7:"grapes",
    8:"jute",
    9:"kidneybeans",
    10:"lentil",
    11:"maize",
    12:"mango",
    13:"mothbeans",
    14:"mungbean",
    15:"muskmelon",
    16:"orange",
    17:"papaya",
    18:"pigeonpeas",
    19:"pomegranate",
    20:"rice",
    21:"watermelon"
}

# %%
import numpy as np

# Assume test_samples is a list or array of shape (num_samples, num_features)
for i, sample in enumerate(test_samples):
    
    # Reshape sample for scikit-learn (1 sample, 7 features)
    sample = np.array(sample).reshape(1, -1)
    
    # Prediction
    prediction = decisionTree.predict(sample)[0]
    
    # Probabilities for all classes
    probabilities = decisionTree.predict_proba(sample)[0]
    
    # Get predicted crop name and confidence
    predicted_crop = crop_labels[prediction].replace('crops_', '')
    confidence = probabilities[list(crop_labels.keys()).index(prediction)]
    
    print(f"Sample {i+1}: {sample.flatten()}")
    print(f"Predicted crop: {predicted_crop} (confidence: {confidence:.3f})")
    
    # Top 3 predictions
    top_3_indices = np.argsort(probabilities)[-3:][::-1]
    print("Top 3 predictions:")
    for idx in top_3_indices:
        # Map index to actual class label
        class_label = list(crop_labels.keys())[idx]
        crop_name = crop_labels[class_label].replace('crops_', '')
        print(f"  - {crop_name}: {probabilities[idx]:.3f}")
    print("-" * 30)
# Out:
# Sample 1: [ 90.    42.    43.    20.88  82.     6.5  202.94]
# Predicted crop: rice (confidence: 1.000)
# Top 3 predictions:
#   - rice: 1.000
#   - watermelon: 0.000
#   - banana: 0.000
# ------------------------------
# Sample 2: [ 40.  40.  40.  25.  80.   7. 150.]
# Predicted crop: mungbean (confidence: 1.000)
# Top 3 predictions:
#   - mungbean: 1.000
#   - watermelon: 0.000
#   - kidneybeans: 0.000
# ------------------------------
# Sample 3: [ 80.   50.   50.   30.   60.    6.8 100. ]
# Predicted crop: maize (confidence: 1.000)
# Top 3 predictions:
#   - maize: 1.000
#   - watermelon: 0.000
#   - kidneybeans: 0.000
# ------------------------------
# C:\Users\vasug\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\vasug\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\vasug\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\vasug\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\vasug\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\vasug\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Accuracy (test accuracy = 97.95% , Training Accuracy = 100%)
